# %% [markdown]
# <a href="https://colab.research.google.com/github/GreeneumNetwork/DEDA-SoSe2021/blob/main/CEED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pvlib

# %%
# !pip install PyEMD

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pip install siphon

# %%
plt.savefig("/content/drive/MyDrive/EMDLSTM1.png",transparent=True)
plt.show()

# %%
pip install EMD-signal

# %%
import math 
from math import log 
from matplotlib import pyplot as plt 
from matplotlib import style

from PyEMD import EEMD 
from PyEMD import CEEMDAN 
from PyEMD import EMD 
from PyEMD import EMD, Visualisation

import pandas as pd 
import numpy as np

#from keras.layers.recurrent 
#import LSTM from keras.models 
#import Sequential from keras.layers.core 
#import Activation, Dense, Dropout model = Sequential()

#from keras.layers import Dense from keras.layers 
#import LSTM from sklearn.preprocessing 
#import MinMaxScaler from sklearn.metrics 
import mean_squared_error

style.use('ggplot')

df1 = ["timestamp","max_power"]

data=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)

max_power_complete=data['max_power'] 
time_complete=pd.to_datetime(data['timestamp'])

max_power = list(islice(max_power_complete, 1500))
time = list(islice(time_complete, 1500))


#mp_max, mp_min = max(max_power), min(max_power) mp_norm = (max_power - mp_min)/(mp_max - mp_min)


if name == "main":
s = np.random.random(100)
eemd = EEMD()
eIMFs = eemd(s)
CEEMDAN
if name == "main":
s = np.random.random(100)
ceemdan = CEEMDAN()
cIMFs = ceemdan(s)
emd = EMD()
IMFs = emd(mp_norm)
plt.plot(IMFs)
model.add(LSTM(units=nb_neural, return_sequences=True, input_shape=
(Xtrain.shape[1], 1)))
model.add(LSTM(units=nb_neural, return_sequences=True, input_shape=
(Xtrain.shape[1], 1)))
model.compile(loss="mse", optimizer="adam", metrics=[rmse, 'mae',
Rsquare])
Fit the LSTM network
history = model.fit(Xtrain, ytrain, batch_size=batch_size,
epochs=num_epochs,
validation_data=(Xval, yval), verbose=2)
ypred = model.predict(mp_norm)

MSE = np.square(np.subtract(mp_norm,ypred)).mean() RMSE = math.sqrt(MSE) print("Root Mean Square Error:\n") print(RMSE)

plt.plot(time,max_power)
plt.plot(time,mp_norm,time,ypred)
plt.legend(np_norm,ypred)
myaxes=fig.add.axes([0.1,0.1,1.6,1.6])
myaxes.plot=year(timestamp, max_power)
plt.show() line_up, = plt.plot(mp_norm, label='mp_norm') line_down, = plt.plot(ypred, label='ypred')

plt.legend(handles=[line_up, line_down])
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=True, ncol=5) plt.title('Solar Energy output') plt.ylabel('KWh') plt.xlabel('Time')

plt.show()
log_np=np.log(max_power)

plt.legend(np_norm,ypred)
# Out:
#   File "<ipython-input-17-0578d26be871>", line 41
#     s = np.random.random(100)
#     ^
# IndentationError: expected an indented block

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import math
from math import log
from matplotlib import style

import pandas as pd
import numpy as np
from math import exp
from math import sqrt

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split 
from datetime import datetime


from keras.layers.core import Activation, Dense, Dropout
model = Sequential()

# reshape into X=t and Y=t+1

# convert an array of values into a dataset matrix
def create_dataset(dataset,look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset

#headers = ['timestamp', 'min_power', 'mean_power', 'max_power','z_normal']
#dtypes = {'timestamp': 'str', 'min_power': 'str', 'mean_power': 'float', 'max_power': 'float','z_normal': 'float'}
#parse_dates = ['timestamp']
#dataframe = pd.read_csv(r'/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', sep='\t', header=None, names=headers, dtype=dtypes, parse_dates=parse_dates)

#dataframe['timestamp']=pd.to_datetime(df['timestamp'])
#df
df1 = ["timestamp","max_power"]

data=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)
data['timestamp']=pd.to_datetime(data['timestamp'])

df_plot=data.iloc[100:220, :]

mp_plot=df_plot['max_power']
time_plot=pd.to_datetime(df_plot['timestamp'])


plt.plot(time_plot,mp_plot)
plt.xlabel("Date")
plt.ylabel("KWh") 
plt.show() 
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/tsne.png', transparent=True )
plt.savefig('/content/drive/MyDrive/Colab Notebooks/tsne.png', dpi=None, facecolor=None, edgecolor='black', orientation='portrait',
            papertype=None, format=None, transparent=True, bbox_inches="tight", pad_inches=0.1, frameon=None, metadata=None)

#dataframe=data.iloc[100:1000, :]           
dataframe=data.iloc[100:1000, 1:2]

dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
#print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
#print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.legend(trainPredict,testPredict)
#myaxes=fig.add.axes([0.1,0.1,1.6,1.6])
#myaxes.plot=year(timestamp, max_power)
plt.xlabel("Date")
plt.ylabel("KWh") 
plt.savefig("/content/drive/MyDrive/EMDLSTM1.png",transparent=True)
plt.show()

r2 = r2_score(dataframe['stationary'], predictions)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
# Epoch 1/100
# 601/601 - 2s - loss: 0.1200
# Epoch 2/100
# 601/601 - 1s - loss: 0.0398
# Epoch 3/100
# 601/601 - 1s - loss: 0.0144
# Epoch 4/100
# 601/601 - 1s - loss: 0.0137
# Epoch 5/100
# 601/601 - 1s - loss: 0.0138
# Epoch 6/100
# 601/601 - 1s - loss: 0.0138
# Epoch 7/100
# 601/601 - 1s - loss: 0.0137
# Epoch 8/100
# 601/601 - 1s - loss: 0.0137
# Epoch 9/100
# 601/601 - 1s - loss: 0.0138
# Epoch 10/100
# 601/601 - 1s - loss: 0.0137
# Epoch 11/100
# 601/601 - 1s - loss: 0.0137
# Epoch 12/100
# 601/601 - 1s - loss: 0.0137
# Epoch 13/100
# 601/601 - 1s - loss: 0.0137
# Epoch 14/100
# 601/601 - 1s - loss: 0.0137
# Epoch 15/100
# 601/601 - 1s - loss: 0.0138
# Epoch 16/100
# 601/601 - 1s - loss: 0.0136
# Epoch 17/100
# 601/601 - 1s - loss: 0.0137
# Epoch 18/100
# ...

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import math
from math import log
from matplotlib import style

import pandas as pd
import numpy as np
from math import exp
from math import sqrt

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split 
from datetime import datetime
from pandas.plotting import scatter_matrix

from keras.layers.core import Activation, Dense, Dropout
model = Sequential()

# reshape into X=t and Y=t+1


#headers = ['timestamp', 'min_power', 'mean_power', 'max_power','z_normal']
#dtypes = {'timestamp': 'str', 'min_power': 'str', 'mean_power': 'float', 'max_power': 'float','z_normal': 'float'}
#parse_dates = ['timestamp']
#dataframe = pd.read_csv(r'/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', sep='\t', header=None, names=headers, dtype=dtypes, parse_dates=parse_dates)

#dataframe['timestamp']=pd.to_datetime(df['timestamp'])
#df
data=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)
data['timestamp']=pd.to_datetime(data['timestamp'])

df_plot=data.iloc[100:220, :]

mp_plot=df_plot['max_power']
time_plot=pd.to_datetime(df_plot['timestamp'])


plt.plot(time_plot,mp_plot)
plt.xlabel("Date)")
plt.ylabel("KWh") 
plt.show() 
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/tsne.png', transparent=True )
plt.savefig('/content/drive/MyDrive/Colab Notebooks/tsne.png', dpi=None, facecolor=None, edgecolor='black', orientation='portrait',
            papertype=None, format=None, transparent=True, bbox_inches="tight", pad_inches=0.1, frameon=None, metadata=None)

n_total=1000
dataframe=data.iloc[0:n_total, :] 

#dataframe=data.iloc[0:n_total, 1:2]
                   

pd.plotting.lag_plot(data['max_power'])
plt.show()
pd.plotting.autocorrelation_plot(data['max_power'])

plt.show()

data['max_power'].corr(data['max_power'].shift(24))

from statsmodels.tsa.seasonal import seasonal_decompose
decomposed = seasonal_decompose(dataframe['max_power'], model='additive',freq=2)
x = decomposed.plot() #See note below about this
plt.show()


dataframe['stationary']=dataframe['max_power'].diff()


from statsmodels.tsa.ar_model import VAR
from statsmodels.tsa.arima_model import ARIMA

#create train/test datasets
X = dataframe['stationary'].dropna()

#train_size =  int(len(X) * 0.80)
#test_size = int(len(X)) - train_size 
#len(train_data) + len(test_data)-1

#train_time=data.iloc[100:train_size, 1:2]
#test_time=data.iloc[train_size:n_total, 1:2]

train_data = X[1:(len(X)-24)]
test_data = X[(len(X)-24):]


#train_data = X[1:len(X)-24]
#test_data = X[X[len(X)-24:]]
#train the autoregression model
model = AR(train_data)
model_fitted = model.fit()

# make Test predictions 
#trainPredict = model_fitted.predict(
 #   start=1, 
  #  end=len(train_data), 
   # dynamic=False)

# make Train predictions 
# make predictions 
predictions = model_fitted.predict(
    start=len(train_data), 
    end=len(train_data) + len(test_data)-1, 
    dynamic=True)

# create a comparison dataframe
compare_df = pd.concat(
    [dataframe['stationary'].tail(24),
    predictions], axis=1).rename(
    columns={'stationary': 'actual', 0:'predicted'})

# create a comparison dataframe
#compare_df = pd.concat(
 #   [dataframe['stationary'].tail(24),
  #  predictions], axis=1).rename(
   # columns={'stationary': 'actual', 0:'predicted'})

#plot the two values
compare_df.plot()

#plt.plot(test_data)
#plt.xlabel("Date)")
#plt.ylabel("KWh") 
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/tsne.png', transparent=True )
#plt.savefig('/content/drive/MyDrive/Colab Notebooks/AR.png', dpi=None, facecolor=None, edgecolor='black', orientation='portrait',
 #           papertype=None, format=None, transparent=True, bbox_inches="tight", pad_inches=0.1, frameon=None, metadata=None)


#plt.plot(X)
#plt.plot(trainPredict)
#plt.plot(testPredict)

plt.xlabel("Date")
plt.ylabel("KWh") 
plt.show() 
plt.savefig('/content/drive/MyDrive/Colab Notebooks/AR.png', dpi=None, facecolor=None, edgecolor='black', orientation='portrait',
            papertype=None, format=None, transparent=True, bbox_inches="tight", pad_inches=0.1, frameon=None, metadata=None)

from sklearn.metrics import r2_score

r2 = r2_score(dataframe['stationary'].tail(24), predictions)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-eea46edd07db> in <module>()
#      80
#      81
# ---> 82 from statsmodels.tsa.ar_model import VAR
#      83 #from statsmodels.tsa.arima_model import ARIMA
#      84
#
# ...

# %%
latitude_deg = 42.206 # positive in the northern hemisphere
longitude_deg = -71.382 # negative reckoning west from prime meridian in Greenwich, England
date = datetime.datetime(2007, 2, 18, 15, 13, 1, 130320, tzinfo=datetime.timezone.utc)
altitude_deg = get_altitude(latitude_deg, longitude_deg, date)
radiation.get_radiation_direct(date, altitude_deg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3a3ec8685c9a> in <module>()
#       2 longitude_deg = -71.382 # negative reckoning west from prime meridian in Greenwich, England
#       3 date = datetime.datetime(2007, 2, 18, 15, 13, 1, 130320, tzinfo=datetime.timezone.utc)
# ----> 4 altitude_deg = get_altitude(latitude_deg, longitude_deg, date)
#       5 radiation.get_radiation_direct(date, altitude_deg)
#
# NameError: name 'get_altitude' is not defined

# %%
import numpy as np

from PyEMD import EMD
from PyEMD import EMD, Visualisation
#from PyEMD import EEMD
#from PyEMD import CEEMDAN
from PyEMD.utils import get_timeline

#t = time
t=data.iloc[0:n_total, 1:1]
S=mp_norm

#S = mp_norm

# Extract imfs and residue
# In case of EMD
emd = EMD()
emd.emd(S)
imfs, res = emd.get_imfs_and_residue()

#EEMD
  #components = EEMD()(S)
   # eemd = EEMD()
   # eIMFs = eemd(S)
   # imfs, res = eemd.get_imfs_and_residue()

#CEEMDAN
   # ceemdan = CEEMDAN()
    #cIMFs = ceemdan(s)
    #imfs, res = ceemd.get_imfs_and_residue()

# In general:
#components = EEMD()(S)
#imfs, res = components[:-1], components[-1]

vis = Visualisation()
vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-8708c6660567> in <module>()
#       3 import numpy as np
#       4
# ----> 5 from PyEMD import EMD
#       6 from PyEMD import EMD, Visualisation
#       7 #from PyEMD import EEMD
#
# ModuleNotFoundError: No module named 'PyEMD'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from PyEMD import EEMD
import numpy as np
import pylab as plt

# Define signal
t = time
S = mp_norm;

#t = np.linspace(0, 1, 200)
#sin = lambda x,p: np.sin(2*np.pi*x*t+p)
#S = 3*sin(18,0.2)*(t-0.2)**2
#S += 5*sin(11,2.7)
#S += 3*sin(14,1.6)
#S += 1*np.sin(4*2*np.pi*(t-0.8)**2)
#S += t**2.1 -t

# Assign EEMD to `eemd` variable
eemd = EEMD()

# Say we want detect extrema using parabolic method
emd = eemd.EMD
emd.extrema_detection="parabol"

# Execute EEMD on S
eIMFs = eemd.eemd(S,t)
nIMFs = eIMFs.shape[0]

# Plot results
plt.figure(figsize=(12,9))
plt.subplot(nIMFs+1, 1, 1)
plt.plot(t, S, 'r')

for n in range(nIMFs):
    plt.subplot(nIMFs+1, 1, n+2)
    plt.plot(t, eIMFs[n], 'g')
    plt.ylabel("eIMF %i" %(n+1))
    plt.locator_params(axis='y', nbins=5)

plt.xlabel("Time [s]")
plt.tight_layout()
plt.savefig('eemd_example', dpi=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-c18ea178b110> in <module>()
# ----> 1 from PyEMD import EEMD
#       2 import numpy as np
#       3 import pylab as plt
#       4
#       5 # Define signal
#
# ModuleNotFoundError: No module named 'PyEMD'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from __future__ import print_function


import itertools
import logging
import numpy as np

from multiprocessing import Pool
from typing import Dict, Optional, Sequence, Tuple, Union

# Beginning of program
if __name__ == "__main__":
    import pylab as plt

    # Logging options
    logging.basicConfig(level=logging.INFO)

    max_imf = -1

    # Signal options
   # N = 500
    #tMin, tMax = 0, 2*np.pi
    #T = np.linspace(tMin, tMax, N)

    #S = 3*np.sin(4*T) + 4*np.cos(9*T) + np.sin(8.11*T+1.2)

    # Prepare and run EEMD
    T=t;
    trials = 200
    ceemdan = CEEMDAN(trials=trials)

    C_IMFs = ceemdan(S, T, max_imf)
    imfNo  = C_IMFs.shape[0]

    # Plot results in a grid
    c = np.floor(np.sqrt(imfNo+2))
    r = np.ceil((imfNo+2)/c)

    plt.ioff()
    plt.subplot(r, c, 1)
    plt.plot(T, S, 'r')
    plt.xlim((tMin, tMax))
    plt.title("Original signal")

    plt.subplot(r, c, 2)
    plt.plot(T, S-np.sum(C_IMFs, axis=0), 'r')
    plt.xlim((tMin, tMax))
    plt.title("Residuum")

    for num in range(imfNo):
        plt.subplot(r, c, num+3)
        plt.plot(T, C_IMFs[num],'g')
        plt.xlim((tMin, tMax))
        plt.title("Imf "+str(num+1))

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f16278fe089c> in <module>()
#      26
#      27     # Prepare and run EEMD
# ---> 28     T=t;
#      29     trials = 200
#      30     ceemdan = CEEMDAN(trials=trials)
#
# NameError: name 't' is not defined

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

df1 = ["timestamp","max_power"]

#series =read_csv(r'/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)
data=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)


df1 = ["timestamp","max_power"]

#data=pd.read_csv(r/maabarot_johnson_from_2010_04_22_to_2020_12_31.csv', usecols=df1)
#data=pd.read_csv(r'/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv', usecols=df1)

max_power_complete=data['max_power']
time_complete=data['timestamp']

#max_power = list(islice(max_power_complete, 1500))
#time = list(islice(time_complete, 1500))

array1 = np.array(max_power_complete)
max_power=array1[1000:2000:1]

array2 = np.array(time_complete)
time=array2[1000:2000:1]

mp_max, mp_min = max(max_power), min(max_power)
mp_norm = (max_power - mp_min)/(mp_max - mp_min)
log_mp=np.log(mp_norm)
#series = read_csv(r/'maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv')
#plot_acf(mp_norm)

plot_pacf(mp_norm)

#plot_acf(log_mp)
#plot_pacf(log_mp)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: RuntimeWarning: divide by zero encountered in log

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

d=sm.tsa.stattools.acf(mp_norm)
fft3=np.fft.fft(d)
plt.show()
plt.plot(fft3, label='fft partly')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d04da9740689> in <module>()
#       4 import statsmodels.api as sm
#       5
# ----> 6 d=sm.tsa.stattools.acf(mp_norm)
#       7 fft3=np.fft.fft(d)
#       8 plt.show()
#
# NameError: name 'mp_norm' is not defined

# %%
sample_rate = 1000
seconds = 10
num_samples = sample_rate*seconds

import numpy as np
time_vect = np.linspace(0, seconds, num_samples)

emd = EMD(extrema_detection='parabol')

freq = 5
nonlinearity_deg = .25  # change extent of deformation from sinusoidal shape [-1 to 1]
nonlinearity_phi = -np.pi/4  # change left-right skew of deformation [-pi to pi]

x = emd
x += np.cos(2*np.pi*1*time_vect)
#Estimate IMFs

imf = emd.sift.sift(x)
#Compute instantaneous frequency, phase and amplitude using the Normalised Hilbert Transform Method.

IP, IF, IA = emd.spectra.frequency_transform(imf, sample_rate, 'hilbert')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-022ecf0467c6> in <module>()
#       6 time_vect = np.linspace(0, seconds, num_samples)
#       7
# ----> 8 emd = EMD(extrema_detection='parabol')
#       9
#      10 freq = 5
#
# NameError: name 'EMD' is not defined

# %%
print(S)
signal=S
analytic_signal = hilbert(S)
amplitude_envelope = np.abs(analytic_signal)
instantaneous_phase = np.unwrap(np.angle(analytic_signal))

fs=24

instantaneous_frequency = (np.diff(instantaneous_phase) /
                           (2.0*np.pi) * fs)
fig, (ax0, ax1) = plt.subplots(nrows=2)
ax0.plot(t, signal, label='signal')
ax0.plot(t, amplitude_envelope, label='envelope')
ax0.set_xlabel("time in seconds")
ax0.legend()
ax1.plot(t[1:], instantaneous_frequency)
ax1.set_xlabel("time in seconds")
ax1.set_ylim(0.0, 120.0)
fig.tight_layout()
# Out:
# [0.59472949 0.37193053 0.15212617 ... 0.         0.         0.        ]
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.layers.core import Activation, Dense, Dropout
model = Sequential()

model.add(LSTM(units=mp_norm, 
return_sequences=True,
input_shape=(Xtrain.shape[1], 1)))

model.add(LSTM(units=nb_neural, return_sequences=True, 
input_shape=(Xtrain.shape[1], 1)))
model.compile(loss="mse", optimizer="adam", metrics=[rmse, 'mae',Rsquare])

#Fit the LSTM network
history = model.fit(Xtrain, ytrain, batch_size=batch_size,
epochs=num_epochs,
validation_data=(Xval, yval), verbose=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1c708d4fe83a> in <module>()
#       4 model = Sequential()
#       5
# ----> 6 model.add(LSTM(units=mp_norm,
#       7 return_sequences=True,
#       8 input_shape=(Xtrain.shape[1], 1)))
#
# NameError: name 'mp_norm' is not defined

# %%
from PyEMD import EMD
from PyEMD import EMD, Visualisation
#from PyEMD import EEMD
from PyEMD import CEEMDAN
import numpy as np
from PyEMD.utils import get_timeline
from PyEMD import EMD, Visualisation

t = time
S = mp_norm

if __name__ == "__main__":
   # s = np.random.random(100)
    ceemdan = CEEMDAN()
    cIMFs = ceemdan(S)

# Extract imfs and residue
# In case of EMD
#emd = EMD()
#emd.emd(S)
#imfs, res = emd.get_imfs_and_residue()


# In general:
components = CEEMDAN()(S)
imfs, res = components[:-1], components[-1]


vis = Visualisation()
vis.plot_imfs(imfs=imfs, residue=res, t=t, include_residue=True)
vis.plot_instant_freq(t, imfs=imfs)
vis.show()

#---------
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c2e53c802db2> in <module>()
#       7 from PyEMD import EMD, Visualisation
#       8
# ----> 9 t = time
#      10 S = mp_norm
#      11
#
# NameError: name 'time' is not defined

# %%
# Extract instantaneous phases and frequencies using Hilbert transform 
instant_phases = instant_phase(imfs)
instant_freqs = np.diff(instant_phases)/(2*np.pi*dt)

# Create a figure consisting of 3 panels which from the top are the input signal, IMFs and instantaneous frequencies
fig, axes = plt.subplots(3, figsize=(12,12))

# The top panel shows the input signal
ax = axes[0]
ax.plot(t, S)
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("Input signal")

# The middle panel shows all IMFs
ax = axes[1]
for num, imf in enumerate(imfs):
    ax.plot(t, imf, label='IMF %s' %(num+1))

# Label the figure
ax.legend()
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("IMFs")

# The bottom panel shows all instantaneous frequencies
ax = axes[2]
for num, instant_freq in enumerate(instant_freqs):
    ax.plot(t[:-1], instant_freq, label='IMF %s'%(num+1))

# Label the figure
ax.legend()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Inst. Freq. [Hz]")
ax.set_title("Huang-Hilbert Transform")

plt.tight_layout()
plt.savefig('hht_example', dpi=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-30fd9a2bacde> in <module>()
#       1 # Extract instantaneous phases and frequencies using Hilbert transform
# ----> 2 instant_phases = instant_phase(imfs)
#       3 instant_freqs = np.diff(instant_phases)/(2*np.pi*dt)
#       4
#       5 # Create a figure consisting of 3 panels which from the top are the input signal, IMFs and instantaneous frequencies
#
# NameError: name 'instant_phase' is not defined

# %% [markdown]
# # New Section

# %%
from dnppy import solar
lat         = 37                    # lat (N positive)
lon         = -76.4                 # lon (E positive)
datestamp   = "20150515-120000"     # date stamp
fmt         = "%Y%m%d-%H%M%S"       # datestamp format
tz          = -4                    # timezone (GMT/UTC) offset
sc  = solar(lat, lon, datestamp, tz, fmt)
sc.compute_all()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e2ef4066c4c7> in <module>()
# ----> 1 from dnppy import solar
#       2 lat         = 37                    # lat (N positive)
#       3 lon         = -76.4                 # lon (E positive)
#       4 datestamp   = "20150515-120000"     # date stamp
#       5 fmt         = "%Y%m%d-%H%M%S"       # datestamp format
#
# ModuleNotFoundError: No module named 'dnppy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose


data=pd.read_csv(r/maabarot_johnson_from_2010_04_22_to_2020_12_31.csv', usecols=df1)
#data=pd.read_csv(r'/maabarot_johnson_from_2010_04_22_to_2020_12_31a.csv')

max_power_complete=data['max_power']
time_complete=data['timestamp']

#max_power = list(islice(max_power_complete, 1500))
#time = list(islice(time_complete, 1500))

p=3601
array1 = np.array(max_power_complete)
max_power=array1[101:p:1]

#np.random.seed(0)
n=2500
#dates = np.array('2010-03-14 15:00:00', dtype=np.datetime64) + np.arange(n)
array2 = np.array(time_complete)
dates =array2[101:p:1]

mp_max, mp_min = max(max_power), min(max_power)

data = (max_power - mp_min)/(mp_max - mp_min)

df = pd.DataFrame({'data': data}, index=dates)

# Reproduce the example in OP

#figure(figsize=(60, 80), dpi=120)

#decompfreq = 24*60
#decompfreq = 24*60/15*1

seasonal_decompose(df, model='additive', freq=24).plot()


ts_index = pd.date_range('1/1/2010', periods=3500, freq='T')
v1 = max_power
#v2 = max_power2
#v3 = max_power3

ts_df = pd.DataFrame({'v1':v1},index=ts_index)
ts_df.head()
hourly_mean_df = ts_df.resample('H').mean() # you can use .sum() also
hourly_mean_df.head()

hourly_mean_df.plot()
# Out:
#   File "<ipython-input-18-2084ac35e98f>", line 6
#     data=pd.read_csv(r/maabarot_johnson_from_2010_04_22_to_2020_12_31.csv', usecols=df1)
#                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
import numpy as np
import pylab as plt
from scipy.signal import hilbert

from PyEMD import EMD


def instant_phase(imfs):
    """Extract analytical signal through Hilbert Transform."""
    analytic_signal = hilbert(imfs)  # Apply Hilbert transform to each row
    phase = np.unwrap(np.angle(analytic_signal))  # Compute angle between img and real
    return phase

# Define signal
#t = np.linspace(0, 1, 200)
#dt = t[1]-t[0]

#sin = lambda x, p: np.sin(2*np.pi*x*t+p)
#S = 3*sin(18, 0.2)*(t-0.2)**2
#S += 5*sin(11, 2.7)
#S += 3*sin(14, 1.6)
#S += 1*np.sin(4*2*np.pi*(t-0.8)**2)
#S += t**2.1 -t

# Compute IMFs with EMD
#emd = EMD()
#imfs = emd(S, t)

# Extract instantaneous phases and frequencies using Hilbert transform 
instant_phases = instant_phase(imfs)
instant_freqs = np.diff(instant_phases)/(2*np.pi*dt)

# Create a figure consisting of 3 panels which from the top are the input signal, IMFs and instantaneous frequencies
fig, axes = plt.subplots(3, figsize=(12,12))

# The top panel shows the input signal
ax = axes[0]
ax.plot(t, S)
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("Input signal")

# The middle panel shows all IMFs
ax = axes[1]
for num, imf in enumerate(imfs):
    ax.plot(t, imf, label='IMF %s' %(num+1))

# Label the figure
ax.legend()
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("IMFs")

# The bottom panel shows all instantaneous frequencies
ax = axes[2]
for num, instant_freq in enumerate(instant_freqs):
    ax.plot(t[:-1], instant_freq, label='IMF %s'%(num+1))

# Label the figure
ax.legend()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Inst. Freq. [Hz]")
ax.set_title("Huang-Hilbert Transform")

plt.tight_layout()
plt.savefig('hht_example', dpi=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ab04b28805de> in <module>()
#      29 # Extract instantaneous phases and frequencies using Hilbert transform
#      30 instant_phases = instant_phase(imfs)
# ---> 31 instant_freqs = np.diff(instant_phases)/(2*np.pi*dt)
#      32
#      33 # Create a figure consisting of 3 panels which from the top are the input signal, IMFs and instantaneous frequencies
#
# NameError: name 'dt' is not defined

# %%
import numpy as np
import pylab as plt
from scipy.signal import hilbert

from PyEMD import EMD


def instant_phase(imfs):
    """Extract analytical signal through Hilbert Transform."""
    analytic_signal = hilbert(imfs)  # Apply Hilbert transform to each row
    phase = np.unwrap(np.angle(analytic_signal))  # Compute angle between img and real
    return phase

# Define signal
t = np.linspace(0, 1, 200)
dt = t[1]-t[0]

sin = lambda x, p: np.sin(2*np.pi*x*t+p)
S = 3*sin(18, 0.2)*(t-0.2)**2
S += 5*sin(11, 2.7)
S += 3*sin(14, 1.6)
S += 1*np.sin(4*2*np.pi*(t-0.8)**2)
S += t**2.1 -t

# Compute IMFs with EMD
emd = EMD()
imfs = emd(S, t)

# Extract instantaneous phases and frequencies using Hilbert transform 
instant_phases = instant_phase(imfs)
instant_freqs = np.diff(instant_phases)/(2*np.pi*dt)

# Create a figure consisting of 3 panels which from the top are the input signal, IMFs and instantaneous frequencies
fig, axes = plt.subplots(3, figsize=(12,12))

# The top panel shows the input signal
ax = axes[0]
ax.plot(t, S)
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("Input signal")

# The middle panel shows all IMFs
ax = axes[1]
for num, imf in enumerate(imfs):
    ax.plot(t, imf, label='IMF %s' %(num+1))

# Label the figure
ax.legend()
ax.set_ylabel("Amplitude [arb. u.]")
ax.set_title("IMFs")

# The bottom panel shows all instantaneous frequencies
ax = axes[2]
for num, instant_freq in enumerate(instant_freqs):
    ax.plot(t[:-1], instant_freq, label='IMF %s'%(num+1))

# Label the figure
ax.legend()
ax.set_xlabel("Time [s]")
ax.set_ylabel("Inst. Freq. [Hz]")
ax.set_title("Huang-Hilbert Transform")

plt.tight_layout()
plt.savefig('hht_example', dpi=120)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-35196c74b490> in <module>()
#       3 from scipy.signal import hilbert
#       4
# ----> 5 from PyEMD import EMD
#       6
#       7
#
# ModuleNotFoundError: No module named 'PyEMD'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
